# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import GridSearchCV

# %%
# Location to the file containing the csv file for the data
csv_file_path = "satellite_data/orbital_elements/unpropagated_elements_Sentinel-3A.csv"

# Reading the csv data file and creating a dataframe
df = pd.read_csv(csv_file_path, index_col = 0, parse_dates = True)

# Creating a dataframe with only the Brouwer Mean Motion
df_bmm = df[["Brouwer mean motion"]]

# Centering and scaling the data
df_bmm = (df_bmm - df_bmm.mean()) * 1e7

# Plotting the Brouwer Mean Motion
sns.lineplot(data = df_bmm)
plt.title("Sentinel-3A - Brouwer Mean Motion")
# Out:
# Text(0.5, 1.0, 'Sentinel-3A - Brouwer Mean Motion')

# %%
""" start_date = pd.to_datetime("2018")
end_date = pd.to_datetime("2021")

# Filtering maneuvers based on the date range
df_bmm = df_bmm[df_bmm.index >= start_date]
df_bmm = df_bmm[df_bmm.index <= end_date]

df_bmm """
# Out:
# ' start_date = pd.to_datetime("2018")\nend_date = pd.to_datetime("2021")\n\n# Filtering maneuvers based on the date range\ndf_bmm = df_bmm[df_bmm.index >= start_date]\ndf_bmm = df_bmm[df_bmm.index <= end_date]\n\ndf_bmm '

# %%
NUM_LAG_FEATURES = 10

# Creating features and labels
df_bmm_y = df_bmm.copy()
df_bmm_x = df_bmm.shift(1)

# Renaming the 1st Lag feature
df_bmm_x = df_bmm_x.rename(columns={"Brouwer mean motion": "bmm_lag_1"})

# Adding the rest of the lag features based on the number of lags
for lag in range(2,NUM_LAG_FEATURES + 1):
    df_bmm_x[f"bmm_lag_{lag}"] = df_bmm.shift(lag)

# %%
df_bmm_x
# Out:
#                             bmm_lag_1  bmm_lag_2  bmm_lag_3  bmm_lag_4  \
# 2016-03-04 15:21:16.747488        NaN        NaN        NaN        NaN
# 2016-03-05 03:07:49.774079  -1.931994        NaN        NaN        NaN
# 2016-03-06 02:41:39.264000  -2.060963  -1.931994        NaN        NaN
# 2016-03-07 05:37:27.298272  -2.457633  -2.060963  -1.931994        NaN
# 2016-03-08 03:30:17.538911  -2.591082  -2.457633  -2.060963  -1.931994
# ...                               ...        ...        ...        ...
# 2022-09-25 03:15:40.345632   0.376035   0.301572   0.193902   0.102836
# 2022-09-26 04:30:28.587167   0.509231   0.376035   0.301572   0.193902
# 2022-09-27 02:23:18.378527   0.588683   0.509231   0.376035   0.301572
# 2022-09-28 01:57:07.361279   0.682117   0.588683   0.509231   0.376035
# 2022-09-29 01:30:56.336255   0.832353   0.682117   0.588683   0.509231
#
#                             bmm_lag_5  bmm_lag_6  bmm_lag_7  bmm_lag_8  \
# 2016-03-04 15:21:16.747488        NaN        NaN        NaN        NaN
# 2016-03-05 03:07:49.774079        NaN        NaN        NaN        NaN
# 2016-03-06 02:41:39.264000        NaN        NaN        NaN        NaN
# 2016-03-07 05:37:27.298272        NaN        NaN        NaN        NaN
# 2016-03-08 03:30:17.538911        NaN        NaN        NaN        NaN
# ...                               ...        ...        ...        ...
# 2022-09-25 03:15:40.345632   0.010896  -0.081482  -0.179976  -0.274538
# 2022-09-26 04:30:28.587167   0.102836   0.010896  -0.081482  -0.179976
# 2022-09-27 02:23:18.378527   0.193902   0.102836   0.010896  -0.081482
# 2022-09-28 01:57:07.361279   0.301572   0.193902   0.102836   0.010896
# 2022-09-29 01:30:56.336255   0.376035   0.301572   0.193902   0.102836
#
#                             bmm_lag_9  bmm_lag_10
# 2016-03-04 15:21:16.747488        NaN         NaN
# 2016-03-05 03:07:49.774079        NaN         NaN
# 2016-03-06 02:41:39.264000        NaN         NaN
# 2016-03-07 05:37:27.298272        NaN         NaN
# 2016-03-08 03:30:17.538911        NaN         NaN
# ...                               ...         ...
# 2022-09-25 03:15:40.345632  -0.341136   -0.414034
# 2022-09-26 04:30:28.587167  -0.274538   -0.341136
# 2022-09-27 02:23:18.378527  -0.179976   -0.274538
# 2022-09-28 01:57:07.361279  -0.081482   -0.179976
# 2022-09-29 01:30:56.336255   0.010896   -0.081482
#
# [2385 rows x 10 columns]

# %%
df_bmm_y
# Out:
#                             Brouwer mean motion
# 2016-03-04 15:21:16.747488            -1.931994
# 2016-03-05 03:07:49.774079            -2.060963
# 2016-03-06 02:41:39.264000            -2.457633
# 2016-03-07 05:37:27.298272            -2.591082
# 2016-03-08 03:30:17.538911            -2.601132
# ...                                         ...
# 2022-09-25 03:15:40.345632             0.509231
# 2022-09-26 04:30:28.587167             0.588683
# 2022-09-27 02:23:18.378527             0.682117
# 2022-09-28 01:57:07.361279             0.832353
# 2022-09-29 01:30:56.336255             0.945012
#
# [2385 rows x 1 columns]

# %%
# Removing rows with NaN values
df_bmm_y = df_bmm_y.iloc[NUM_LAG_FEATURES:]
df_bmm_x = df_bmm_x.iloc[NUM_LAG_FEATURES:]

# %%
# Train Test data splitting based on date
SPLIT_DATE = "2020-01-20"
df_bmm_x_train = df_bmm_x[:SPLIT_DATE]
df_bmm_x_test = df_bmm_x[SPLIT_DATE:]
df_bmm_y_train = df_bmm_y[:SPLIT_DATE]
df_bmm_y_test = df_bmm_y[SPLIT_DATE:]

# %%
# Getting the training data percentage
train_percentage = df_bmm_y_train.size / (df_bmm_y_train.size + df_bmm_y_test.size)
print(round(train_percentage*100,2))
# Out:
# 59.01

# %%
# Getting the testing data percentage
test_percentage = df_bmm_y_test.size / (df_bmm_y_train.size + df_bmm_y_test.size)
print(round(test_percentage*100,2))
# Out:
# 40.99

# %%
# Using grid search to find the best hyperparameters
def grid_search_xgboost(X_train, y_train, cv = 5, verbose = 1):
    param_grid = {
        'n_estimators': [100,1000,1500,2000],
        'max_depth': [5,7,9],
        'learning_rate': [0.01,0.001,0.1],
        'colsample_bytree': [0.5,0.8,1],
        'min_child_weight': [3,5,7]
    }

    xgb_model = XGBRegressor(random_state = 25)

    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=cv,
        verbose=verbose,
        n_jobs=1
    )

    grid_search.fit(X_train,y_train)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    print("Best Parameters Found:")
    print(best_params)

    return best_model, best_params

best_xgb_model, best_xgb_params = grid_search_xgboost(df_bmm_x_train,df_bmm_y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Parameters Found:
# {'colsample_bytree': 1, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 1000}

# %%
# Creating the XGBoost regressor with early stopping to avoid overfitting
xgb_regressor = XGBRegressor(
    n_estimators = 1000,
    max_depth = 5,
    learning_rate = 0.01,
    colsample_bytree = 1,
    min_child_weight = 5,
    #subsample = 1,
    eval_metric = 'mae',
    early_stopping_rounds = 10
)

# %%
# Fitting the XGBoost model
xgb_regressor.fit(
    df_bmm_x_train,
    df_bmm_y_train,
    eval_set = [(df_bmm_x_train,df_bmm_y_train), (df_bmm_x_test,df_bmm_y_test)],
    verbose = True
)
# Out:
# [0]	validation_0-mae:0.82693	validation_1-mae:0.88552
# [1]	validation_0-mae:0.81933	validation_1-mae:0.87793
# [2]	validation_0-mae:0.81181	validation_1-mae:0.87042
# [3]	validation_0-mae:0.80436	validation_1-mae:0.86300
# [4]	validation_0-mae:0.79699	validation_1-mae:0.85562
# [5]	validation_0-mae:0.78970	validation_1-mae:0.84836
# [6]	validation_0-mae:0.78248	validation_1-mae:0.84114
# [7]	validation_0-mae:0.77535	validation_1-mae:0.83403
# [8]	validation_0-mae:0.76830	validation_1-mae:0.82699
# [9]	validation_0-mae:0.76131	validation_1-mae:0.82000
# [10]	validation_0-mae:0.75439	validation_1-mae:0.81308
# [11]	validation_0-mae:0.74754	validation_1-mae:0.80625
# [12]	validation_0-mae:0.74076	validation_1-mae:0.79947
# [13]	validation_0-mae:0.73403	validation_1-mae:0.79282
# [14]	validation_0-mae:0.72739	validation_1-mae:0.78619
# [15]	validation_0-mae:0.72080	validation_1-mae:0.77965
# [16]	validation_0-mae:0.71429	validation_1-mae:0.77319
# [17]	validation_0-mae:0.70786	validation_1-mae:0.76679
# [18]	validation_0-mae:0.70147	validation_1-mae:0.76047
# [19]	validation_0-mae:0.69517	validation_1-mae:0.75420
# [20]	validation_0-mae:0.68890	validation_1-mae:0.74798
# [21]	validation_0-mae:0.68274	validation_1-mae:0.74185
# [22]	validation_0-mae:0.67658	validation_1-mae:0.73574
# [23]	validation_0-mae:0.67050	validation_1-mae:0.72978
# [24]	validation_0-mae:0.66446	validation_1-mae:0.72376
# [25]	validation_0-mae:0.65850	validation_1-mae:0.71790
# [26]	validation_0-mae:0.65256	validation_1-mae:0.71205
# [27]	validation_0-mae:0.64673	validation_1-mae:0.70623
# [28]	validation_0-mae:0.64091	validation_1-mae:0.70049
# [29]	validation_0-mae:0.63519	validation_1-mae:0.69479
# [30]	validation_0-mae:0.62953	validation_1-mae:0.68917
# [31]	validation_0-mae:0.62391	validation_1-mae:0.68352
# [32]	validation_0-mae:0.61838	validation_1-mae:0.67803
# [33]	validation_0-mae:0.61285	validation_1-mae:0.67256
# [34]	validation_0-mae:0.60743	validation_1-mae:0.66718
# [35]	validation_0-mae:0.60204	validation_1-mae:0.66183
# [36]	validation_0-mae:0.59669	validation_1-mae:0.65649
# [37]	validation_0-mae:0.59142	validation_1-mae:0.65117
# [38]	validation_0-mae:0.58620	validation_1-mae:0.64598
# [39]	validation_0-mae:0.58099	validation_1-mae:0.64083
# [40]	validation_0-mae:0.57589	validation_1-mae:0.63575
# [41]	validation_0-mae:0.57084	validation_1-mae:0.63062
# [42]	validation_0-mae:0.56582	validation_1-mae:0.62563
# [43]	validation_0-mae:0.56084	validation_1-mae:0.62068
# [44]	validation_0-mae:0.55595	validation_1-mae:0.61577
# [45]	validation_0-mae:0.55109	validation_1-mae:0.61094
# [46]	validation_0-mae:0.54628	validation_1-mae:0.60613
# [47]	validation_0-mae:0.54152	validation_1-mae:0.60136
# [48]	validation_0-mae:0.53681	validation_1-mae:0.59664
# [49]	validation_0-mae:0.53216	validation_1-mae:0.59201
# [50]	validation_0-mae:0.52754	validation_1-mae:0.58741
# [51]	validation_0-mae:0.52299	validation_1-mae:0.58280
# [52]	validation_0-mae:0.51850	validation_1-mae:0.57830
# [53]	validation_0-mae:0.51402	validation_1-mae:0.57383
# [54]	validation_0-mae:0.50958	validation_1-mae:0.56939
# [55]	validation_0-mae:0.50519	validation_1-mae:0.56500
# [56]	validation_0-mae:0.50087	validation_1-mae:0.56067
# [57]	validation_0-mae:0.49658	validation_1-mae:0.55636
# [58]	validation_0-mae:0.49231	validation_1-mae:0.55212
# [59]	validation_0-mae:0.48811	validation_1-mae:0.54792
# [60]	validation_0-mae:0.48393	validation_1-mae:0.54371
# [61]	validation_0-mae:0.47981	validation_1-mae:0.53959
# [62]	validation_0-mae:0.47570	validation_1-mae:0.53551
# [63]	validation_0-mae:0.47163	validation_1-mae:0.53147
# [64]	validation_0-mae:0.46762	validation_1-mae:0.52745
# [65]	validation_0-mae:0.46367	validation_1-mae:0.52351
# [66]	validation_0-mae:0.45973	validation_1-mae:0.51958
# [67]	validation_0-mae:0.45586	validation_1-mae:0.51571
# [68]	validation_0-mae:0.45202	validation_1-mae:0.51188
# [69]	validation_0-mae:0.44821	validation_1-mae:0.50811
# [70]	validation_0-mae:0.44444	validation_1-mae:0.50434
# [71]	validation_0-mae:0.44071	validation_1-mae:0.50063
# [72]	validation_0-mae:0.43701	validation_1-mae:0.49698
# [73]	validation_0-mae:0.43333	validation_1-mae:0.49327
# [74]	validation_0-mae:0.42969	validation_1-mae:0.48963
# [75]	validation_0-mae:0.42611	validation_1-mae:0.48609
# [76]	validation_0-mae:0.42255	validation_1-mae:0.48247
# [77]	validation_0-mae:0.41903	validation_1-mae:0.47900
# [78]	validation_0-mae:0.41556	validation_1-mae:0.47549
# [79]	validation_0-mae:0.41212	validation_1-mae:0.47206
# [80]	validation_0-mae:0.40871	validation_1-mae:0.46871
# [81]	validation_0-mae:0.40530	validation_1-mae:0.46532
# [82]	validation_0-mae:0.40192	validation_1-mae:0.46197
# [83]	validation_0-mae:0.39862	validation_1-mae:0.45867
# [84]	validation_0-mae:0.39532	validation_1-mae:0.45540
# [85]	validation_0-mae:0.39205	validation_1-mae:0.45214
# [86]	validation_0-mae:0.38881	validation_1-mae:0.44888
# [87]	validation_0-mae:0.38559	validation_1-mae:0.44564
# [88]	validation_0-mae:0.38240	validation_1-mae:0.44246
# [89]	validation_0-mae:0.37924	validation_1-mae:0.43930
# [90]	validation_0-mae:0.37617	validation_1-mae:0.43621
# [91]	validation_0-mae:0.37309	validation_1-mae:0.43311
# [92]	validation_0-mae:0.37001	validation_1-mae:0.43004
# [93]	validation_0-mae:0.36696	validation_1-mae:0.42698
# [94]	validation_0-mae:0.36400	validation_1-mae:0.42401
# [95]	validation_0-mae:0.36101	validation_1-mae:0.42103
# [96]	validation_0-mae:0.35812	validation_1-mae:0.41812
# [97]	validation_0-mae:0.35526	validation_1-mae:0.41521
# [98]	validation_0-mae:0.35235	validation_1-mae:0.41230
# [99]	validation_0-mae:0.34953	validation_1-mae:0.40946
# [100]	validation_0-mae:0.34670	validation_1-mae:0.40662
# [101]	validation_0-mae:0.34395	validation_1-mae:0.40386
# [102]	validation_0-mae:0.34124	validation_1-mae:0.40109
# [103]	validation_0-mae:0.33850	validation_1-mae:0.39834
# [104]	validation_0-mae:0.33577	validation_1-mae:0.39558
# [105]	validation_0-mae:0.33314	validation_1-mae:0.39286
# [106]	validation_0-mae:0.33048	validation_1-mae:0.39017
# [107]	validation_0-mae:0.32789	validation_1-mae:0.38753
# [108]	validation_0-mae:0.32529	validation_1-mae:0.38490
# [109]	validation_0-mae:0.32276	validation_1-mae:0.38228
# [110]	validation_0-mae:0.32019	validation_1-mae:0.37970
# [111]	validation_0-mae:0.31765	validation_1-mae:0.37715
# [112]	validation_0-mae:0.31521	validation_1-mae:0.37468
# [113]	validation_0-mae:0.31273	validation_1-mae:0.37220
# [114]	validation_0-mae:0.31028	validation_1-mae:0.36974
# [115]	validation_0-mae:0.30783	validation_1-mae:0.36732
# [116]	validation_0-mae:0.30549	validation_1-mae:0.36497
# [117]	validation_0-mae:0.30310	validation_1-mae:0.36257
# [118]	validation_0-mae:0.30072	validation_1-mae:0.36020
# [119]	validation_0-mae:0.29845	validation_1-mae:0.35793
# [120]	validation_0-mae:0.29613	validation_1-mae:0.35561
# [121]	validation_0-mae:0.29384	validation_1-mae:0.35330
# [122]	validation_0-mae:0.29163	validation_1-mae:0.35110
# [123]	validation_0-mae:0.28943	validation_1-mae:0.34887
# [124]	validation_0-mae:0.28723	validation_1-mae:0.34669
# [125]	validation_0-mae:0.28508	validation_1-mae:0.34450
# [126]	validation_0-mae:0.28294	validation_1-mae:0.34243
# [127]	validation_0-mae:0.28081	validation_1-mae:0.34033
# [128]	validation_0-mae:0.27867	validation_1-mae:0.33817
# [129]	validation_0-mae:0.27656	validation_1-mae:0.33607
# [130]	validation_0-mae:0.27452	validation_1-mae:0.33398
# [131]	validation_0-mae:0.27245	validation_1-mae:0.33192
# [132]	validation_0-mae:0.27040	validation_1-mae:0.32987
# [133]	validation_0-mae:0.26841	validation_1-mae:0.32789
# [134]	validation_0-mae:0.26640	validation_1-mae:0.32590
# [135]	validation_0-mae:0.26446	validation_1-mae:0.32394
# [136]	validation_0-mae:0.26252	validation_1-mae:0.32202
# [137]	validation_0-mae:0.26062	validation_1-mae:0.32011
# [138]	validation_0-mae:0.25869	validation_1-mae:0.31817
# [139]	validation_0-mae:0.25680	validation_1-mae:0.31630
# [140]	validation_0-mae:0.25494	validation_1-mae:0.31445
# [141]	validation_0-mae:0.25311	validation_1-mae:0.31259
# [142]	validation_0-mae:0.25130	validation_1-mae:0.31086
# [143]	validation_0-mae:0.24948	validation_1-mae:0.30900
# [144]	validation_0-mae:0.24767	validation_1-mae:0.30721
# [145]	validation_0-mae:0.24589	validation_1-mae:0.30543
# [146]	validation_0-mae:0.24415	validation_1-mae:0.30366
# [147]	validation_0-mae:0.24236	validation_1-mae:0.30193
# [148]	validation_0-mae:0.24062	validation_1-mae:0.30023
# [149]	validation_0-mae:0.23888	validation_1-mae:0.29854
# [150]	validation_0-mae:0.23718	validation_1-mae:0.29684
# [151]	validation_0-mae:0.23550	validation_1-mae:0.29520
# [152]	validation_0-mae:0.23383	validation_1-mae:0.29358
# [153]	validation_0-mae:0.23218	validation_1-mae:0.29194
# [154]	validation_0-mae:0.23055	validation_1-mae:0.29025
# [155]	validation_0-mae:0.22897	validation_1-mae:0.28865
# [156]	validation_0-mae:0.22737	validation_1-mae:0.28709
# [157]	validation_0-mae:0.22578	validation_1-mae:0.28555
# [158]	validation_0-mae:0.22420	validation_1-mae:0.28398
# [159]	validation_0-mae:0.22265	validation_1-mae:0.28246
# [160]	validation_0-mae:0.22114	validation_1-mae:0.28093
# [161]	validation_0-mae:0.21962	validation_1-mae:0.27946
# [162]	validation_0-mae:0.21811	validation_1-mae:0.27800
# [163]	validation_0-mae:0.21662	validation_1-mae:0.27647
# [164]	validation_0-mae:0.21514	validation_1-mae:0.27503
# [165]	validation_0-mae:0.21368	validation_1-mae:0.27359
# [166]	validation_0-mae:0.21222	validation_1-mae:0.27215
# [167]	validation_0-mae:0.21078	validation_1-mae:0.27078
# [168]	validation_0-mae:0.20936	validation_1-mae:0.26939
# [169]	validation_0-mae:0.20791	validation_1-mae:0.26796
# [170]	validation_0-mae:0.20650	validation_1-mae:0.26655
# [171]	validation_0-mae:0.20511	validation_1-mae:0.26524
# [172]	validation_0-mae:0.20375	validation_1-mae:0.26386
# [173]	validation_0-mae:0.20240	validation_1-mae:0.26250
# [174]	validation_0-mae:0.20104	validation_1-mae:0.26122
# [175]	validation_0-mae:0.19969	validation_1-mae:0.25992
# [176]	validation_0-mae:0.19834	validation_1-mae:0.25864
# [177]	validation_0-mae:0.19703	validation_1-mae:0.25731
# [178]	validation_0-mae:0.19574	validation_1-mae:0.25601
# [179]	validation_0-mae:0.19446	validation_1-mae:0.25472
# [180]	validation_0-mae:0.19319	validation_1-mae:0.25343
# [181]	validation_0-mae:0.19195	validation_1-mae:0.25220
# [182]	validation_0-mae:0.19071	validation_1-mae:0.25094
# [183]	validation_0-mae:0.18950	validation_1-mae:0.24975
# [184]	validation_0-mae:0.18829	validation_1-mae:0.24852
# [185]	validation_0-mae:0.18710	validation_1-mae:0.24731
# [186]	validation_0-mae:0.18591	validation_1-mae:0.24615
# [187]	validation_0-mae:0.18474	validation_1-mae:0.24497
# [188]	validation_0-mae:0.18358	validation_1-mae:0.24379
# [189]	validation_0-mae:0.18240	validation_1-mae:0.24259
# [190]	validation_0-mae:0.18124	validation_1-mae:0.24143
# [191]	validation_0-mae:0.18012	validation_1-mae:0.24031
# [192]	validation_0-mae:0.17900	validation_1-mae:0.23920
# [193]	validation_0-mae:0.17788	validation_1-mae:0.23815
# [194]	validation_0-mae:0.17680	validation_1-mae:0.23707
# [195]	validation_0-mae:0.17569	validation_1-mae:0.23602
# [196]	validation_0-mae:0.17460	validation_1-mae:0.23500
# [197]	validation_0-mae:0.17354	validation_1-mae:0.23396
# [198]	validation_0-mae:0.17247	validation_1-mae:0.23291
# [199]	validation_0-mae:0.17141	validation_1-mae:0.23193
# [200]	validation_0-mae:0.17034	validation_1-mae:0.23089
# [201]	validation_0-mae:0.16930	validation_1-mae:0.22993
# [202]	validation_0-mae:0.16826	validation_1-mae:0.22892
# [203]	validation_0-mae:0.16725	validation_1-mae:0.22795
# [204]	validation_0-mae:0.16627	validation_1-mae:0.22699
# [205]	validation_0-mae:0.16527	validation_1-mae:0.22599
# [206]	validation_0-mae:0.16429	validation_1-mae:0.22503
# [207]	validation_0-mae:0.16332	validation_1-mae:0.22407
# [208]	validation_0-mae:0.16237	validation_1-mae:0.22315
# [209]	validation_0-mae:0.16143	validation_1-mae:0.22221
# [210]	validation_0-mae:0.16051	validation_1-mae:0.22131
# [211]	validation_0-mae:0.15959	validation_1-mae:0.22044
# [212]	validation_0-mae:0.15868	validation_1-mae:0.21956
# [213]	validation_0-mae:0.15779	validation_1-mae:0.21868
# [214]	validation_0-mae:0.15690	validation_1-mae:0.21782
# [215]	validation_0-mae:0.15600	validation_1-mae:0.21698
# [216]	validation_0-mae:0.15513	validation_1-mae:0.21614
# [217]	validation_0-mae:0.15424	validation_1-mae:0.21527
# [218]	validation_0-mae:0.15339	validation_1-mae:0.21446
# [219]	validation_0-mae:0.15253	validation_1-mae:0.21366
# [220]	validation_0-mae:0.15168	validation_1-mae:0.21287
# [221]	validation_0-mae:0.15084	validation_1-mae:0.21209
# [222]	validation_0-mae:0.15002	validation_1-mae:0.21133
# [223]	validation_0-mae:0.14920	validation_1-mae:0.21058
# [224]	validation_0-mae:0.14838	validation_1-mae:0.20986
# [225]	validation_0-mae:0.14757	validation_1-mae:0.20912
# [226]	validation_0-mae:0.14679	validation_1-mae:0.20838
# [227]	validation_0-mae:0.14598	validation_1-mae:0.20761
# [228]	validation_0-mae:0.14522	validation_1-mae:0.20689
# [229]	validation_0-mae:0.14446	validation_1-mae:0.20619
# [230]	validation_0-mae:0.14369	validation_1-mae:0.20550
# [231]	validation_0-mae:0.14291	validation_1-mae:0.20476
# [232]	validation_0-mae:0.14218	validation_1-mae:0.20408
# [233]	validation_0-mae:0.14144	validation_1-mae:0.20344
# [234]	validation_0-mae:0.14071	validation_1-mae:0.20280
# [235]	validation_0-mae:0.13999	validation_1-mae:0.20214
# [236]	validation_0-mae:0.13930	validation_1-mae:0.20148
# [237]	validation_0-mae:0.13857	validation_1-mae:0.20078
# [238]	validation_0-mae:0.13789	validation_1-mae:0.20018
# [239]	validation_0-mae:0.13722	validation_1-mae:0.19956
# [240]	validation_0-mae:0.13651	validation_1-mae:0.19890
# [241]	validation_0-mae:0.13581	validation_1-mae:0.19825
# [242]	validation_0-mae:0.13517	validation_1-mae:0.19769
# [243]	validation_0-mae:0.13448	validation_1-mae:0.19705
# [244]	validation_0-mae:0.13386	validation_1-mae:0.19652
# [245]	validation_0-mae:0.13321	validation_1-mae:0.19593
# [246]	validation_0-mae:0.13254	validation_1-mae:0.19531
# [247]	validation_0-mae:0.13191	validation_1-mae:0.19470
# [248]	validation_0-mae:0.13124	validation_1-mae:0.19416
# [249]	validation_0-mae:0.13061	validation_1-mae:0.19358
# [250]	validation_0-mae:0.13000	validation_1-mae:0.19301
# [251]	validation_0-mae:0.12942	validation_1-mae:0.19249
# [252]	validation_0-mae:0.12877	validation_1-mae:0.19198
# [253]	validation_0-mae:0.12817	validation_1-mae:0.19144
# [254]	validation_0-mae:0.12758	validation_1-mae:0.19089
# [255]	validation_0-mae:0.12700	validation_1-mae:0.19035
# [256]	validation_0-mae:0.12645	validation_1-mae:0.18985
# [257]	validation_0-mae:0.12588	validation_1-mae:0.18933
# [258]	validation_0-mae:0.12532	validation_1-mae:0.18884
# [259]	validation_0-mae:0.12475	validation_1-mae:0.18833
# [260]	validation_0-mae:0.12422	validation_1-mae:0.18784
# [261]	validation_0-mae:0.12368	validation_1-mae:0.18736
# [262]	validation_0-mae:0.12314	validation_1-mae:0.18686
# [263]	validation_0-mae:0.12263	validation_1-mae:0.18642
# [264]	validation_0-mae:0.12213	validation_1-mae:0.18592
# [265]	validation_0-mae:0.12161	validation_1-mae:0.18547
# [266]	validation_0-mae:0.12110	validation_1-mae:0.18498
# [267]	validation_0-mae:0.12060	validation_1-mae:0.18451
# [268]	validation_0-mae:0.12013	validation_1-mae:0.18406
# [269]	validation_0-mae:0.11966	validation_1-mae:0.18362
# [270]	validation_0-mae:0.11921	validation_1-mae:0.18320
# [271]	validation_0-mae:0.11872	validation_1-mae:0.18281
# [272]	validation_0-mae:0.11821	validation_1-mae:0.18246
# [273]	validation_0-mae:0.11774	validation_1-mae:0.18201
# [274]	validation_0-mae:0.11729	validation_1-mae:0.18164
# [275]	validation_0-mae:0.11683	validation_1-mae:0.18126
# [276]	validation_0-mae:0.11638	validation_1-mae:0.18082
# [277]	validation_0-mae:0.11591	validation_1-mae:0.18045
# [278]	validation_0-mae:0.11545	validation_1-mae:0.18009
# [279]	validation_0-mae:0.11500	validation_1-mae:0.17969
# [280]	validation_0-mae:0.11455	validation_1-mae:0.17934
# [281]	validation_0-mae:0.11414	validation_1-mae:0.17895
# [282]	validation_0-mae:0.11371	validation_1-mae:0.17855
# [283]	validation_0-mae:0.11328	validation_1-mae:0.17822
# [284]	validation_0-mae:0.11287	validation_1-mae:0.17785
# [285]	validation_0-mae:0.11243	validation_1-mae:0.17748
# [286]	validation_0-mae:0.11203	validation_1-mae:0.17711
# [287]	validation_0-mae:0.11163	validation_1-mae:0.17673
# [288]	validation_0-mae:0.11123	validation_1-mae:0.17633
# [289]	validation_0-mae:0.11084	validation_1-mae:0.17597
# [290]	validation_0-mae:0.11044	validation_1-mae:0.17566
# [291]	validation_0-mae:0.11006	validation_1-mae:0.17531
# [292]	validation_0-mae:0.10969	validation_1-mae:0.17496
# [293]	validation_0-mae:0.10930	validation_1-mae:0.17465
# [294]	validation_0-mae:0.10892	validation_1-mae:0.17433
# [295]	validation_0-mae:0.10855	validation_1-mae:0.17395
# [296]	validation_0-mae:0.10817	validation_1-mae:0.17363
# [297]	validation_0-mae:0.10776	validation_1-mae:0.17336
# [298]	validation_0-mae:0.10742	validation_1-mae:0.17310
# [299]	validation_0-mae:0.10708	validation_1-mae:0.17281
# [300]	validation_0-mae:0.10672	validation_1-mae:0.17252
# [301]	validation_0-mae:0.10635	validation_1-mae:0.17226
# [302]	validation_0-mae:0.10602	validation_1-mae:0.17197
# [303]	validation_0-mae:0.10565	validation_1-mae:0.17173
# [304]	validation_0-mae:0.10528	validation_1-mae:0.17148
# [305]	validation_0-mae:0.10496	validation_1-mae:0.17121
# [306]	validation_0-mae:0.10463	validation_1-mae:0.17093
# [307]	validation_0-mae:0.10427	validation_1-mae:0.17071
# [308]	validation_0-mae:0.10396	validation_1-mae:0.17044
# [309]	validation_0-mae:0.10364	validation_1-mae:0.17018
# [310]	validation_0-mae:0.10334	validation_1-mae:0.16993
# [311]	validation_0-mae:0.10300	validation_1-mae:0.16972
# [312]	validation_0-mae:0.10271	validation_1-mae:0.16949
# [313]	validation_0-mae:0.10241	validation_1-mae:0.16922
# [314]	validation_0-mae:0.10212	validation_1-mae:0.16898
# [315]	validation_0-mae:0.10182	validation_1-mae:0.16879
# [316]	validation_0-mae:0.10151	validation_1-mae:0.16856
# [317]	validation_0-mae:0.10121	validation_1-mae:0.16834
# [318]	validation_0-mae:0.10093	validation_1-mae:0.16813
# [319]	validation_0-mae:0.10061	validation_1-mae:0.16795
# [320]	validation_0-mae:0.10033	validation_1-mae:0.16777
# [321]	validation_0-mae:0.10007	validation_1-mae:0.16755
# [322]	validation_0-mae:0.09980	validation_1-mae:0.16732
# [323]	validation_0-mae:0.09949	validation_1-mae:0.16713
# [324]	validation_0-mae:0.09924	validation_1-mae:0.16697
# [325]	validation_0-mae:0.09893	validation_1-mae:0.16679
# [326]	validation_0-mae:0.09869	validation_1-mae:0.16664
# [327]	validation_0-mae:0.09845	validation_1-mae:0.16648
# [328]	validation_0-mae:0.09822	validation_1-mae:0.16633
# [329]	validation_0-mae:0.09793	validation_1-mae:0.16618
# [330]	validation_0-mae:0.09770	validation_1-mae:0.16603
# [331]	validation_0-mae:0.09742	validation_1-mae:0.16589
# [332]	validation_0-mae:0.09720	validation_1-mae:0.16576
# [333]	validation_0-mae:0.09693	validation_1-mae:0.16558
# [334]	validation_0-mae:0.09672	validation_1-mae:0.16544
# [335]	validation_0-mae:0.09645	validation_1-mae:0.16530
# [336]	validation_0-mae:0.09624	validation_1-mae:0.16517
# [337]	validation_0-mae:0.09603	validation_1-mae:0.16505
# [338]	validation_0-mae:0.09582	validation_1-mae:0.16490
# [339]	validation_0-mae:0.09556	validation_1-mae:0.16480
# [340]	validation_0-mae:0.09534	validation_1-mae:0.16465
# [341]	validation_0-mae:0.09514	validation_1-mae:0.16454
# [342]	validation_0-mae:0.09493	validation_1-mae:0.16439
# [343]	validation_0-mae:0.09468	validation_1-mae:0.16423
# [344]	validation_0-mae:0.09451	validation_1-mae:0.16414
# [345]	validation_0-mae:0.09434	validation_1-mae:0.16405
# [346]	validation_0-mae:0.09418	validation_1-mae:0.16397
# [347]	validation_0-mae:0.09401	validation_1-mae:0.16387
# [348]	validation_0-mae:0.09384	validation_1-mae:0.16378
# [349]	validation_0-mae:0.09366	validation_1-mae:0.16367
# [350]	validation_0-mae:0.09351	validation_1-mae:0.16360
# [351]	validation_0-mae:0.09334	validation_1-mae:0.16349
# [352]	validation_0-mae:0.09317	validation_1-mae:0.16338
# [353]	validation_0-mae:0.09301	validation_1-mae:0.16328
# [354]	validation_0-mae:0.09285	validation_1-mae:0.16321
# [355]	validation_0-mae:0.09270	validation_1-mae:0.16312
# [356]	validation_0-mae:0.09254	validation_1-mae:0.16304
# [357]	validation_0-mae:0.09238	validation_1-mae:0.16295
# [358]	validation_0-mae:0.09222	validation_1-mae:0.16284
# [359]	validation_0-mae:0.09207	validation_1-mae:0.16276
# [360]	validation_0-mae:0.09193	validation_1-mae:0.16269
# [361]	validation_0-mae:0.09177	validation_1-mae:0.16260
# [362]	validation_0-mae:0.09162	validation_1-mae:0.16252
# [363]	validation_0-mae:0.09149	validation_1-mae:0.16245
# [364]	validation_0-mae:0.09137	validation_1-mae:0.16240
# [365]	validation_0-mae:0.09122	validation_1-mae:0.16233
# [366]	validation_0-mae:0.09107	validation_1-mae:0.16226
# [367]	validation_0-mae:0.09092	validation_1-mae:0.16220
# [368]	validation_0-mae:0.09080	validation_1-mae:0.16217
# [369]	validation_0-mae:0.09067	validation_1-mae:0.16210
# [370]	validation_0-mae:0.09054	validation_1-mae:0.16205
# [371]	validation_0-mae:0.09039	validation_1-mae:0.16199
# [372]	validation_0-mae:0.09026	validation_1-mae:0.16192
# [373]	validation_0-mae:0.09013	validation_1-mae:0.16187
# [374]	validation_0-mae:0.09003	validation_1-mae:0.16182
# [375]	validation_0-mae:0.08989	validation_1-mae:0.16178
# [376]	validation_0-mae:0.08977	validation_1-mae:0.16171
# [377]	validation_0-mae:0.08963	validation_1-mae:0.16167
# [378]	validation_0-mae:0.08950	validation_1-mae:0.16160
# [379]	validation_0-mae:0.08937	validation_1-mae:0.16154
# [380]	validation_0-mae:0.08928	validation_1-mae:0.16152
# [381]	validation_0-mae:0.08915	validation_1-mae:0.16146
# [382]	validation_0-mae:0.08904	validation_1-mae:0.16139
# [383]	validation_0-mae:0.08892	validation_1-mae:0.16133
# [384]	validation_0-mae:0.08881	validation_1-mae:0.16126
# [385]	validation_0-mae:0.08867	validation_1-mae:0.16125
# [386]	validation_0-mae:0.08856	validation_1-mae:0.16120
# [387]	validation_0-mae:0.08844	validation_1-mae:0.16116
# [388]	validation_0-mae:0.08834	validation_1-mae:0.16112
# [389]	validation_0-mae:0.08823	validation_1-mae:0.16107
# [390]	validation_0-mae:0.08811	validation_1-mae:0.16109
# [391]	validation_0-mae:0.08801	validation_1-mae:0.16105
# [392]	validation_0-mae:0.08790	validation_1-mae:0.16101
# [393]	validation_0-mae:0.08780	validation_1-mae:0.16098
# [394]	validation_0-mae:0.08769	validation_1-mae:0.16098
# [395]	validation_0-mae:0.08759	validation_1-mae:0.16095
# [396]	validation_0-mae:0.08749	validation_1-mae:0.16092
# [397]	validation_0-mae:0.08740	validation_1-mae:0.16087
# [398]	validation_0-mae:0.08730	validation_1-mae:0.16090
# [399]	validation_0-mae:0.08723	validation_1-mae:0.16089
# [400]	validation_0-mae:0.08714	validation_1-mae:0.16085
# [401]	validation_0-mae:0.08706	validation_1-mae:0.16082
# [402]	validation_0-mae:0.08701	validation_1-mae:0.16087
# [403]	validation_0-mae:0.08692	validation_1-mae:0.16083
# [404]	validation_0-mae:0.08684	validation_1-mae:0.16081
# [405]	validation_0-mae:0.08675	validation_1-mae:0.16077
# [406]	validation_0-mae:0.08672	validation_1-mae:0.16077
# [407]	validation_0-mae:0.08663	validation_1-mae:0.16078
# [408]	validation_0-mae:0.08655	validation_1-mae:0.16076
# [409]	validation_0-mae:0.08647	validation_1-mae:0.16073
# [410]	validation_0-mae:0.08640	validation_1-mae:0.16070
# [411]	validation_0-mae:0.08636	validation_1-mae:0.16075
# [412]	validation_0-mae:0.08629	validation_1-mae:0.16072
# [413]	validation_0-mae:0.08620	validation_1-mae:0.16068
# [414]	validation_0-mae:0.08618	validation_1-mae:0.16069
# [415]	validation_0-mae:0.08610	validation_1-mae:0.16071
# [416]	validation_0-mae:0.08602	validation_1-mae:0.16067
# [417]	validation_0-mae:0.08598	validation_1-mae:0.16068
# [418]	validation_0-mae:0.08593	validation_1-mae:0.16066
# [419]	validation_0-mae:0.08585	validation_1-mae:0.16063
# [420]	validation_0-mae:0.08582	validation_1-mae:0.16067
# [421]	validation_0-mae:0.08576	validation_1-mae:0.16072
# [422]	validation_0-mae:0.08569	validation_1-mae:0.16068
# [423]	validation_0-mae:0.08566	validation_1-mae:0.16072
# [424]	validation_0-mae:0.08563	validation_1-mae:0.16072
# [425]	validation_0-mae:0.08560	validation_1-mae:0.16076
# [426]	validation_0-mae:0.08558	validation_1-mae:0.16079
# [427]	validation_0-mae:0.08553	validation_1-mae:0.16078
# [428]	validation_0-mae:0.08551	validation_1-mae:0.16081
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#              device=None, early_stopping_rounds=10, enable_categorical=False,
#              eval_metric='mae', feature_types=None, gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Generating the feature importance plot
feature_importance = xgb_regressor.get_booster().get_score(importance_type = "weight")
sns.barplot(x = list(feature_importance.keys()), y = list(feature_importance.values()))
plt.xlabel("Features")
plt.ylabel("Importance (Weight)")
plt.title("Feature Importance Plot")
plt.show()

# %%
# Defining the format of the maneuver text file
columns_widths = [
    (0,5),      # Satellite Name
    (6,10),     # Begining of manueuver year    
    (11,14),    # Begining of manueuver day       
    (15,17),    # Begining of manueuver hour 
    (18,20),    # Begining of manueuver minute 
    (21,25),    # End of manueuver year 
    (26,29),    # End of manueuver day 
    (30,32),    # End of manueuver hour 
    (33,35),    # End of manueuver minute 
    (36,39),    # Manuever type
    (40,43),    # Manuever parameter type
    (44,45)     # Number of burns
]

# Function to parse each line based on column widths defined
def parse_line(line):
    data = [
        line[start:end].strip()
        for start, end in columns_widths
    ]
    return data

# Function to convert start and end maneuver to datetime
def convert_to_datetime(row):
    start_date = datetime.strptime(f"{row['Start_Year']} {row['Start_Day']} {row['Start_Hour']} {row['Start_Minute']}", "%Y %j %H %M")
    end_date = datetime.strptime(f"{row['End_Year']} {row['End_Day']} {row['End_Hour']} {row['End_Minute']}", "%Y %j %H %M")
    return start_date, end_date

# File path to maneuver file
maneuver_file_path = 'satellite_data/manoeuvres/s3aman.txt'

# Reading the text file into a list of lines
with open(maneuver_file_path, 'r') as txt_file:
    lines = txt_file.readlines()

# Parsing each line into a list of values
parsed_data = [parse_line(line) for line in lines]

# Defining the column names
column_names = [
    'Satellite', 'Start_Year', 'Start_Day', 'Start_Hour', 'Start_Minute',
    'End_Year', 'End_Day', 'End_Hour', 'End_Minute',
    'Maneuver_Type', 'Parameter_Type', 'Number_of_Burns'
]

# Creating a dataframe with the text file data
df = pd.DataFrame(parsed_data, columns = column_names)

# Converting start and end maneuvers to datetime
df['Start_Date'], df['End_Date'] = zip(*df.apply(convert_to_datetime,axis=1))

# Checking the dataframe
print(df.head())
# Out:
#   Satellite Start_Year Start_Day Start_Hour Start_Minute End_Year End_Day  \
# 0     SEN3A       2016       053         09           30     2016     053
# 1     SEN3A       2016       054         10           45     2016     054
# 2     SEN3A       2016       055         19           29     2016     055
# 3     SEN3A       2016       057         09           27     2016     057
# 4     SEN3A       2016       062         12           59     2016     062
#
#   End_Hour End_Minute Maneuver_Type Parameter_Type Number_of_Burns  \
# 0       12         11                          006               2
# 1       13         24                          006               2
# 2       19         32                          006               1
# 3       12         08                          006               2
# 4       15         33                          006               2
#
#            Start_Date            End_Date
# 0 2016-02-22 09:30:00 2016-02-22 12:11:00
# 1 2016-02-23 10:45:00 2016-02-23 13:24:00
# 2 2016-02-24 19:29:00 2016-02-24 19:32:00
# 3 2016-02-26 09:27:00 2016-02-26 12:08:00
# 4 2016-03-02 12:59:00 2016-03-02 15:33:00

# %%
# Generating predictions
predictions = xgb_regressor.predict(df_bmm_x_test)

# Calculating residuals
residuals = df_bmm_y_test['Brouwer mean motion'].to_numpy() - predictions

# Creating a data frame for plotting
df_y_plotting = df_bmm_y_test.copy()
df_y_plotting["residuals"] = residuals
df_y_plotting["predictions"] = predictions

# Creating subplots
fig, axes = plt.subplots(2, 1, figsize = (10,10))

# Plotting actual vs predicted values
sns.lineplot(x = df_bmm_y_test.index, y = df_bmm_y_test["Brouwer mean motion"], label = "Actual", ax = axes[0])
sns.lineplot(x = df_y_plotting.index, y = df_y_plotting["predictions"], label = "Predicted", ax = axes[0])
axes[0].set_title("Actual vs Predicted Brouwer Mean Motion - CryoSat-2", fontsize=20)
axes[0].set_xlabel("Date",fontsize=16)
axes[0].set_ylabel("Brouwer Mean Motion",fontsize=16)
axes[0].legend(fontsize=14)
axes[0].tick_params(axis='both',labelsize=14)

# Plotting residuals
sns.lineplot(x = df_y_plotting.index, y = df_y_plotting["residuals"], label = "Residuals", ax = axes[1])
axes[1].set_title("Residuals of XGBoost Model - Sentinel-3A", fontsize=20)
axes[1].set_xlabel("Date", fontsize=16)
axes[1].set_ylabel("Residuals", fontsize=16)
axes[1].tick_params(axis='both',labelsize=14)

start_date = pd.to_datetime("2020")
end_date = pd.to_datetime("2022-09")

# Filtering maneuvers based on the date range
maneuvers_filtered = df[df["Start_Date"] >= start_date]
maneuvers_filtered = maneuvers_filtered[maneuvers_filtered["Start_Date"] <= end_date]

# Marking maneuvers on the residuals plot
maneuver_dates = maneuvers_filtered['Start_Date']
first_label = True
for maneuver_date in maneuver_dates:
    if first_label:
        axes[1].axvline(x = maneuver_date, color = 'red', linestyle = '--', label = "Maneuvers")
        first_label = False
    else:
        axes[1].axvline(x = maneuver_date, color = 'red', linestyle = '--')     
axes[1].legend(fontsize=14)

plt.tight_layout()
plt.show()

# %%
df_y_plotting
# Out:
#                             Brouwer mean motion  residuals  predictions
# 2020-01-20 11:21:46.263168            -0.314875  -0.064294    -0.250581
# 2020-01-21 04:11:38.503680            -0.303331  -0.052750    -0.250581
# 2020-01-22 03:45:27.637632            -0.267574  -0.025178    -0.242395
# 2020-01-23 03:19:16.770720            -0.232253  -0.009592    -0.222661
# 2020-01-24 04:34:05.127168            -0.212662  -0.036862    -0.175800
# ...                                         ...        ...          ...
# 2022-09-25 03:15:40.345632             0.509231   0.106371     0.402860
# 2022-09-26 04:30:28.587167             0.588683   0.149065     0.439618
# 2022-09-27 02:23:18.378527             0.682117   0.220089     0.462027
# 2022-09-28 01:57:07.361279             0.832353   0.125218     0.707134
# 2022-09-29 01:30:56.336255             0.945012   0.080099     0.864913
#
# [974 rows x 3 columns]

# %%
# Getting absolute values of the residuals for the anomaly statistic as a series
residuals_series = df_y_plotting["residuals"].sort_values().abs()
residuals_series = pd.Series(residuals_series, index = df_bmm.index)
residuals_series =residuals_series.dropna()
residuals_series
# Out:
# 2020-01-20 11:21:46.263168    0.064294
# 2020-01-21 04:11:38.503680    0.052750
# 2020-01-22 03:45:27.637632    0.025178
# 2020-01-23 03:19:16.770720    0.009592
# 2020-01-24 04:34:05.127168    0.036862
#                                 ...
# 2022-09-25 03:15:40.345632    0.106371
# 2022-09-26 04:30:28.587167    0.149065
# 2022-09-27 02:23:18.378527    0.220089
# 2022-09-28 01:57:07.361279    0.125218
# 2022-09-29 01:30:56.336255    0.080099
# Name: residuals, Length: 974, dtype: float64

# %%
# Getting the maneuver time stamps into a series in date time format
maneuver_dates_series = pd.Series(pd.to_datetime(df.Start_Date))
maneuver_dates_series
# Out:
# 0    2016-02-22 09:30:00
# 1    2016-02-23 10:45:00
# 2    2016-02-24 19:29:00
# 3    2016-02-26 09:27:00
# 4    2016-03-02 12:59:00
#              ...
# 59   2022-05-18 06:08:00
# 60   2022-06-14 09:30:00
# 61   2022-07-21 06:41:00
# 62   2022-08-25 08:13:00
# 63   2022-10-06 07:00:00
# Name: Start_Date, Length: 64, dtype: datetime64[ns]

# %%
import pandas as pd
import numpy as np

def convert_timestamp_series_to_epoch(series):
    return (
        (series - pd.Timestamp(year=1970, month=1, day=1)) // pd.Timedelta(seconds=1)
    ).values

def compute_simple_matching_precision_recall_for_one_threshold(
    float_matching_max_days,
    float_threshold,
    pd_series_ground_truth_manoeuvre_timestamps,
    pd_series_predictions,
):
    """
    :param float_matching_max_days:
    :param float_threshold:
    :param pd_series_ground_truth_manoeuvre_timestamps:
    :param pd_series_predictions: The index of this series should be the timestamps of the predictions.
    :return: (precision, recall)

   Computes the precision and recall at one anomaly threshold.

   Does this using an implementation of the framework proposed by Zhao:
   Zhao, L. (2021). Event prediction in the big data era: A systematic survey. ACM Computing Surveys (CSUR), 54(5), 1-37.
   https://doi.org/10.1145/3450287

   The method matches each manoeuvre prediction with the closest ground-truth manoeuvre, if it is within a time window.

   Predictions with a match are then true positives and those without a match are false positives. Ground-truth manoeuvres
   with no matching prediction are counted as false negatives.
   """

    matching_max_distance_seconds = pd.Timedelta(days=float_matching_max_days).total_seconds()

    dict_predictions_to_ground_truth = {}
    dict_ground_truth_to_predictions = {}

    np_manoeuvre_timestamps_seconds = convert_timestamp_series_to_epoch(pd_series_ground_truth_manoeuvre_timestamps)
    np_pred_time_stamps_seconds = convert_timestamp_series_to_epoch(pd_series_predictions.index)
    np_predictions = pd_series_predictions.to_numpy()

    for i in range(np_predictions.shape[0]):
        if np_predictions[i] >= float_threshold:
            left_index = np.searchsorted(
                np_manoeuvre_timestamps_seconds, np_pred_time_stamps_seconds[i]
            )

            if left_index != 0:
                left_index -= 1

            index_of_closest = left_index

            if (left_index < pd_series_ground_truth_manoeuvre_timestamps.shape[0] - 1) and (
                abs(np_manoeuvre_timestamps_seconds[left_index] - np_pred_time_stamps_seconds[i])
                > abs(np_manoeuvre_timestamps_seconds[left_index + 1] - np_pred_time_stamps_seconds[i])
            ):
                index_of_closest = left_index + 1

            diff = abs(np_manoeuvre_timestamps_seconds[index_of_closest] - np_pred_time_stamps_seconds[i])

            if diff < matching_max_distance_seconds:
                dict_predictions_to_ground_truth[i] = (
                    index_of_closest,
                    diff,
                )
                if index_of_closest in dict_ground_truth_to_predictions:
                    dict_ground_truth_to_predictions[index_of_closest].append(i)
                else:
                    dict_ground_truth_to_predictions[index_of_closest] = [i]

    np_positive_prediction_indices = np.argwhere(np_predictions >= float_threshold)[:, 0]
    list_false_positives = [
        pred_ind for pred_ind in np_positive_prediction_indices if pred_ind not in dict_predictions_to_ground_truth.keys()
    ]
    list_false_negatives = [
        true_ind for true_ind in np.arange(0, len(pd_series_ground_truth_manoeuvre_timestamps))
        if true_ind not in dict_ground_truth_to_predictions.keys()
    ]

    precision = len(dict_ground_truth_to_predictions) / (len(dict_ground_truth_to_predictions) + len(list_false_positives)) if (len(dict_ground_truth_to_predictions) + len(list_false_positives)) > 0 else 0
    recall = len(dict_ground_truth_to_predictions) / (len(dict_ground_truth_to_predictions) + len(list_false_negatives)) if (len(dict_ground_truth_to_predictions) + len(list_false_negatives)) > 0 else 0

    total_negatives = len(np_predictions) - len(pd_series_ground_truth_manoeuvre_timestamps)
    fpr = len(list_false_positives)/total_negatives

    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall)/(precision + recall)

    return (precision, recall, fpr, f1_score)

# Create plot with precision and recall values for different thresholds
def plot_precision_recall_against_threshold_curve(threshold_range, precisions, recalls):
    plt.figure(figsize=(5,5))
    plt.plot(threshold_range, precisions, marker='o', label='Precision', color='red')
    plt.plot(threshold_range, recalls, marker='x', label='Recall', color='green')
    plt.xlabel('Threshold')
    plt.ylabel('Score')
    plt.title('Precision and Recall vs. Threshold - Sentinel-3A')
    plt.legend()
    plt.grid(True)
    plt.show()

# Calculating precision and recall for multiple thresholds
def compute_precision_recall_fpr_for_multiple_thresholds(
    float_matching_max_days,
    threshold_range,
    pd_series_ground_truth_manoeuvre_timestamps,
    pd_series_predictions,
):
    precisions = []
    recalls = []
    fprs = []
    f1_scores = []

    for threshold in threshold_range:
        precision, recall, fpr, f1_score = compute_simple_matching_precision_recall_for_one_threshold(
            float_matching_max_days,
            threshold,
            pd_series_ground_truth_manoeuvre_timestamps,
            pd_series_predictions,
        )
        precisions.append(precision)
        recalls.append(recall)
        fprs.append(fpr)
        f1_scores.append(f1_score)

    return precisions, recalls, fprs, f1_scores

if __name__ == "__main__":

    float_matching_max_days = 3
    threshold_range = np.linspace(0,5,25)

    precisions, recalls, fprs, f1_scores = compute_precision_recall_fpr_for_multiple_thresholds(
    float_matching_max_days,
    threshold_range,
    maneuver_dates_series,
    residuals_series,
    )

    plot_precision_recall_against_threshold_curve(threshold_range,precisions,recalls)

# %%
# Create plot with precision and recall
def plot_precision_recall_curve(precisions, recalls):
    plt.figure(figsize=(5,5))
    plt.plot(recalls, precisions, marker = 'o', label='Precision', color='red')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision and Recall - Sentinel-3A')
    plt.ylim(0,1)
    plt.legend()
    plt.grid(True)
    plt.show()

plot_precision_recall_curve(precisions, recalls)

# %%
# Create roc plot
def plot_roc_curve(fprs, recalls):
    plt.figure(figsize=(5,5))
    plt.plot(fprs, recalls, marker = 'o', label = 'ROC Curve', color='red')
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (Recall)')
    plt.title('ROC Curve - Sentinel-3A')
    plt.plot([0,1], [0,1], 'k--')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_roc_curve(fprs, recalls)

# %%
# Create f1_score vs threshold
def plot_f1_score_curve(threshold_range, f1_scores):
    plt.figure(figsize=(5,5))
    plt.plot(threshold_range, f1_scores, marker = 'o', label = 'F1 Score', color='red')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title('F1 Score vs. Threshold - Sentinel-3A')
    plt.ylim(0,1)
    plt.legend()
    plt.grid(True)
    plt.show()

plot_f1_score_curve(threshold_range, f1_scores)

# %%
# Finding the max f1 score and the relevant threshold
max_index = np.argmax(f1_scores)
max_val = f1_scores[max_index]
max_val_threshold = threshold_range[max_index]

print(max_val)
print(max_val_threshold)
# Out:
# 0.5274725274725275
# 0.625

# %%
# Finding the precision and recall for max f1 score
precision, recall, fpr, f1_score = compute_simple_matching_precision_recall_for_one_threshold(
            float_matching_max_days,
            max_val_threshold,
            maneuver_dates_series,
            residuals_series,
        )

print(precision)
print(recall)
# Out:
# 0.8888888888888888
# 0.375
